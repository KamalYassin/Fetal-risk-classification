# %% [markdown]
# # 01 Data Exploration
#
# Use this notebook to inspect one CTG record before building features or models.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

from src.data.load_ctg import (
    get_fhr_uc_signals,
    load_record,
    plot_record,
    print_record_metadata,
)

# %%
record = load_record('1121')
print_record_metadata(record)

fhr, uc = get_fhr_uc_signals(record)
print('First 10 FHR values:', fhr[:10] if fhr is not None else 'not available')
print('First 10 UC values:', uc[:10] if uc is not None else 'not available')

# %%
plot_record(record)
